# %%
dictionary ={'7487687891506695479': '🔥 Quebrando tudo! Anitta arrasa e deixa todo mundo babando!', 
'7485806549492010245': '@jovempannews pra não perda'}

for url, video_id in dictionary.items():
    print (url)
    print(video_id)
# Out:
# 7487687891506695479
# 🔥 Quebrando tudo! Anitta arrasa e deixa todo mundo babando!
# 7485806549492010245
# @jovempannews pra não perda

# %%
lista1 = [0,1,2,3]

lista1[1:3]
# Out:
# [1, 2]
